# %%
from yelpapi import YelpAPI
import json
import pandas as pd

# %%
# students must use their own username here instead of "brend"
with open('/Users/sherlin01/.secret/yelp_api.json') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['Client-ID', 'API Key'])

# %%
yelp_api = YelpAPI(login['API Key'], timeout_s=5.0)
yelp_api

# %%
Chicken_Fresno = yelp_api.search_query(location='Fresno, TX',
                                       term='Chicken')
type(Chicken_Fresno)
Chicken_Fresno.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
chicken = pd.DataFrame(Chicken_Fresno['businesses'])
chicken.head(2)
# Out:
#                        id                            alias  \
# 0  waguhjeCnyyIv_5PkBDcIQ  daves-hot-chicken-missouri-city
# 1  aMalXw3fbhjiEURWeb4irw         slim-chickens-pearland-2
#
#                  name                                          image_url  \
# 0  Dave's Hot Chicken  https://s3-media1.fl.yelpcdn.com/bphoto/LE-VoO...
# 1       Slim Chickens  https://s3-media2.fl.yelpcdn.com/bphoto/1LAfXk...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/daves-hot-chicken-mis...           134
# 1      False  https://www.yelp.com/biz/slim-chickens-pearlan...            59
#
#                                           categories  rating  \
# 0  [{'alias': 'chickenshop', 'title': 'Chicken Sh...     4.0
# 1  [{'alias': 'southern', 'title': 'Southern'}, {...     3.0
#
#                                          coordinates        transactions  \
# ...

# %%
Chicken_Fresno['total']
# Out:
# 863

# %%
# The assignment only asks for two pages
chicken_offset = yelp_api.search_query(location='Fresno, TX',
                                       term='chicken',
                               offset = 20)

# %%
chicken2 = pd.DataFrame(chicken_offset['businesses'])
chicken2.head(2)
# Out:
#                        id                            alias  \
# 0  urVrcivmfARIDburyb2TrQ  taqueria-el-taco-grill-rosharon
# 1  2AFXIbll-8sDgugwTH4KoQ         one-stop-missouri-city-4
#
#                      name                                          image_url  \
# 0  Taqueria El Taco Grill  https://s3-media2.fl.yelpcdn.com/bphoto/QTv7uO...
# 1                One Stop  https://s3-media4.fl.yelpcdn.com/bphoto/w-k61h...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/taqueria-el-taco-gril...            52
# 1      False  https://www.yelp.com/biz/one-stop-missouri-cit...             4
#
#                                           categories  rating  \
# 0  [{'alias': 'foodtrucks', 'title': 'Food Trucks'}]     4.5
# 1  [{'alias': 'servicestations', 'title': 'Gas St...     4.0
#
#                                        coordinates transactions price  \
# ...

# %%
#now concatenate all pages
all_chicken = pd.concat([chicken, chicken2],
                      ignore_index=True)
display(all_chicken.head(3), all_chicken.tail(3))
# Out:
#                        id                            alias  \
# 0  waguhjeCnyyIv_5PkBDcIQ  daves-hot-chicken-missouri-city
# 1  aMalXw3fbhjiEURWeb4irw         slim-chickens-pearland-2
# 2  uj3VM1PKUZGQOnlaAu4vhQ           pollo-bravo-pearland-2
#
#                  name                                          image_url  \
# 0  Dave's Hot Chicken  https://s3-media1.fl.yelpcdn.com/bphoto/LE-VoO...
# 1       Slim Chickens  https://s3-media2.fl.yelpcdn.com/bphoto/1LAfXk...
# 2         Pollo Bravo  https://s3-media2.fl.yelpcdn.com/bphoto/9oIh8D...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/daves-hot-chicken-mis...           134
# 1      False  https://www.yelp.com/biz/slim-chickens-pearlan...            59
# 2      False  https://www.yelp.com/biz/pollo-bravo-pearland-...             6
#
#                                           categories  rating  \
# ...

# %%
all_chicken.to_json(orient='records')
# Out:
# '[{"id":"waguhjeCnyyIv_5PkBDcIQ","alias":"daves-hot-chicken-missouri-city","name":"Dave\'s Hot Chicken","image_url":"https:\\/\\/s3-media1.fl.yelpcdn.com\\/bphoto\\/LE-VoOFfCOZzzJPyuJCAmQ\\/o.jpg","is_closed":false,"url":"https:\\/\\/www.yelp.com\\/biz\\/daves-hot-chicken-missouri-city?adjust_creative=rZiFgfUX1eajVOVygdFykg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=rZiFgfUX1eajVOVygdFykg","review_count":134,"categories":[{"alias":"chickenshop","title":"Chicken Shop"},{"alias":"halal","title":"Halal"},{"alias":"sandwiches","title":"Sandwiches"}],"rating":4.0,"coordinates":{"latitude":29.5626609753,"longitude":-95.5625694708},"transactions":["delivery","pickup"],"price":"$$","location":{"address1":"6324 Hwy\\u00a06 S","address2":null,"address3":null,"city":"Missouri City","zip_code":"77459","country":"US","state":"TX","display_address":["6324 Hwy\\u00a06 S","Missouri City, TX 77459"]},"phone":"+18329874799","display_phone":"(832) 987-4799","distance":9394.43
# ...
